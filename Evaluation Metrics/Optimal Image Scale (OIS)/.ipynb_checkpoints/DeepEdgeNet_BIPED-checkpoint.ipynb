# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import imageio
import numpy as np

# %%
import sklearn.metrics

def flatten(nested_list):
    return np.asarray(nested_list).flatten()

def OIS(label, output):
	label_matrix = flatten(label.astype('float'))
	label_matrix = (label_matrix == 255)
	output_matrix = flatten(output.astype('float'))
	OIS_results = []
	for threshold in range(256):
		threshold_matrix = (output_matrix >= threshold)
		OIS_result = sklearn.metrics.f1_score(label_matrix, threshold_matrix)
		OIS_results.append(OIS_result)
		# print(OIS_result)
	
	return max(OIS_results)

# %%
import time

gdrive_path = '/content/drive/My Drive/CS 230/Project/'
labels_path = gdrive_path + "datasets/BIPED/edges/edge_maps/train/rgbr/real/"
output_path = gdrive_path + "Canny Detector/Canny-Edge BIPED/sobel_output/"
save_path = gdrive_path + "Evaluation Metrics/Optimal Image Scale (OIS)/Sobel_BIPED.txt"

img_name = os.listdir(labels_path)
outputs = os.listdir(output_path)

if os.path.exists(save_path):
  save_file = open(save_path, 'r+')
else:
  save_file = open(save_path, 'w+')
lines = save_file.readlines()

totalOIS = 0
img_name.sort()
outputs.sort()
assert len(img_name) == len(outputs)

for i in range(len(img_name)):
  if i < len(lines):
    ois = float(lines[i].split(',')[1])
  else:
    assert img_name[i].split('.')[0] == outputs[i].split('.')[0]
    label_img = imageio.imread(labels_path + img_name[i])
    output_img = imageio.imread(output_path + outputs[i])
    ois = OIS(label_img, output_img)
    save_file.write(img_name[i].split('.')[0] + ',' + str(ois) + '\n')

  totalOIS += ois

  t = time.localtime()
  current_time = time.strftime("%H:%M:%S", t)
  print(current_time, img_name[i], ois)

averageOIS = totalOIS / len(img_name)
print("OIS is " + str(averageOIS) + " over " + str(len(img_name)) + " images.")
# Out:
# 09:05:43 RGB_001.png 0.243548059337533
# 09:05:43 RGB_002.png 0.2770502427154788
# 09:05:43 RGB_003.png 0.28073469387755107
# 09:05:43 RGB_004.png 0.22139309229525236
# 09:05:43 RGB_005.png 0.2736372206510287
# 09:05:43 RGB_006.png 0.3743044336743852
# 09:05:43 RGB_007.png 0.2582101167315175
# 09:05:43 RGB_009.png 0.22691428705140906
# 09:05:43 RGB_011.png 0.24217939006256484
# 09:05:43 RGB_012.png 0.2527915185073412
# 09:05:43 RGB_013.png 0.2867191086420329
# 09:05:43 RGB_014.png 0.2915976515416618
# 09:05:43 RGB_015.png 0.23932114834131565
# 09:05:43 RGB_016.png 0.20153143208462
# 09:05:43 RGB_018.png 0.2893030794165316
# 09:05:43 RGB_019.png 0.24853900902744616
# 09:05:43 RGB_020.png 0.2542202000878939
# 09:05:43 RGB_021.png 0.25637093500518693
# 09:05:43 RGB_022.png 0.22508932631715717
# 09:05:43 RGB_023.png 0.29320333336589843
# 09:05:43 RGB_024.png 0.25085910652920956
# 09:05:43 RGB_026.png 0.24343639509516285
# 09:05:43 RGB_027.png 0.24495058014611085
# 09:05:43 RGB_028.png 0.24597563808954825
# 09:05:43 RGB_030.png 0.19517397680309292
# 09:05:43 RGB_031.png 0.23003247084771378
