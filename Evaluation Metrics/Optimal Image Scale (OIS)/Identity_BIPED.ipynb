# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import imageio
import numpy as np

# %%
import sklearn.metrics

def flatten(nested_list):
    return np.asarray(nested_list).flatten()

def OIS(label, output):
	label_matrix = flatten(label.astype('float'))
	label_matrix = (label_matrix == 255)
	output_matrix = flatten(output.astype('float'))
	OIS_results = []
	for threshold in range(256):
		threshold_matrix = (output_matrix >= threshold)
		OIS_result = sklearn.metrics.f1_score(label_matrix, threshold_matrix)
		OIS_results.append(OIS_result)
		# print(OIS_result)
	
	return max(OIS_results)

# %%
import time

gdrive_path = '/content/drive/My Drive/CS 230/Project/'
labels_path = gdrive_path + "datasets/BIPED/edges/edge_maps/train/rgbr/real/"
output_path = gdrive_path + "datasets/BIPED/edges/edge_maps/train/rgbr/real/"
save_path = gdrive_path + "Evaluation Metrics/Optimal Image Scale (OIS)/Identity_BIPED.txt"

img_name = os.listdir(labels_path)
outputs = os.listdir(output_path)

if os.path.exists(save_path):
  save_file = open(save_path, 'r+')
else:
  save_file = open(save_path, 'w+')
lines = save_file.readlines()

totalOIS = 0
img_name.sort()
outputs.sort()
assert len(img_name) == len(outputs)

for i in range(len(img_name)):
  if i < len(lines):
    ois = float(lines[i].split(',')[1])
  else:
    assert img_name[i].split('.')[0] == outputs[i].split('.')[0]
    label_img = imageio.imread(labels_path + img_name[i])
    output_img = imageio.imread(output_path + outputs[i])
    ois = OIS(label_img, output_img)
    save_file.write(img_name[i].split('.')[0] + ',' + str(ois) + '\n')

  totalOIS += ois

  t = time.localtime()
  current_time = time.strftime("%H:%M:%S", t)
  print(current_time, img_name[i], ois)

averageOIS = totalOIS / len(img_name)
print("OIS is " + str(averageOIS) + " over " + str(len(img_name)) + " images.")
# Out:
# 09:05:40 RGB_001.png 1.0
# 09:05:40 RGB_002.png 1.0
# 09:05:40 RGB_003.png 1.0
# 09:05:40 RGB_004.png 1.0
# 09:05:40 RGB_005.png 1.0
# 09:05:40 RGB_006.png 1.0
# 09:05:40 RGB_007.png 1.0
# 09:05:40 RGB_009.png 1.0
# 09:05:40 RGB_011.png 1.0
# 09:05:40 RGB_012.png 1.0
# 09:05:40 RGB_013.png 1.0
# 09:05:40 RGB_014.png 1.0
# 09:05:40 RGB_015.png 1.0
# 09:05:40 RGB_016.png 1.0
# 09:05:40 RGB_018.png 1.0
# 09:05:40 RGB_019.png 1.0
# 09:05:40 RGB_020.png 1.0
# 09:05:40 RGB_021.png 1.0
# 09:05:40 RGB_022.png 1.0
# 09:05:40 RGB_023.png 1.0
# 09:05:40 RGB_024.png 1.0
# 09:05:40 RGB_026.png 1.0
# 09:05:40 RGB_027.png 1.0
# 09:05:40 RGB_028.png 1.0
# 09:05:40 RGB_030.png 1.0
# 09:05:40 RGB_031.png 1.0
# 09:05:40 RGB_032.png 1.0
# 09:05:40 RGB_034.png 1.0
# 09:05:40 RGB_036.png 1.0
# 09:05:40 RGB_037.png 1.0
# 09:05:40 RGB_038.png 1.0
# 09:05:40 RGB_040.png 1.0
# 09:05:40 RGB_041.png 1.0
# 09:05:40 RGB_043.png 1.0
# 09:05:40 RGB_044.png 1.0
# 09:05:40 RGB_045.png 1.0
# 09:05:40 RGB_046.png 1.0
# 09:05:40 RGB_047.png 1.0
# 09:05:40 RGB_048.png 1.0
# 09:05:40 RGB_049.png 1.0
# 09:05:40 RGB_050.png 1.0
