# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import imageio
import numpy as np

# %%
def AveragePrecision(label, output):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	label_matrix = label.astype('float')
	output_matrix = output.astype('float')
	totalPrecision, numRel = 0, 0
	for i in range(len(label_matrix)):
		for j in range(len(label_matrix[i])):
			if label_matrix[i][j] == 255:
				numRel += 1
				totalPrecision += output_matrix[i][j] / 255
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return totalPrecision / numRel

# %%
gdrive_path = '/content/drive/My Drive/CS 230/Project/'
labels_path = gdrive_path + "datasets/BIPED/edges/edge_maps/train/rgbr/real/"
output_path = gdrive_path + "Canny Detector/Canny-Edge BIPED/canny_output/"

img_name = os.listdir(labels_path)
outputs = os.listdir(output_path)

totalPrecision = 0
img_name.sort()
outputs.sort()
assert len(img_name) == len(outputs)

for i in range(len(img_name)):
  assert img_name[i].split('.')[0] == outputs[i].split('.')[0]
  label_img = imageio.imread(labels_path + img_name[i])
  output_img = imageio.imread(output_path + outputs[i])
  AP = AveragePrecision(label_img, output_img)
  totalPrecision += AP
  print(img_name[i], AP)

meanAveragePrecision = totalPrecision / len(img_name)
print("mean AveragePrecision is " + str(meanAveragePrecision) + " over " + str(len(img_name)) + " images.")
# Out:
# RGB_001.png 0.19956806644352593
# RGB_002.png 0.23874270786649993
# RGB_003.png 0.2615121576527271
# RGB_004.png 0.1698806636654507
# RGB_005.png 0.23770373014070148
# RGB_006.png 0.3093892659428451
# RGB_007.png 0.20868005405286794
# RGB_009.png 0.17929261435808594
# RGB_011.png 0.22932599609685508
# RGB_012.png 0.2087810586019394
# RGB_013.png 0.17308499393383822
# RGB_014.png 0.2534881107260889
# RGB_015.png 0.23793147242171547
# RGB_016.png 0.21093561594665436
# RGB_018.png 0.2749332548670468
# RGB_019.png 0.20047655641828896
# RGB_020.png 0.1759041969936349
# RGB_021.png 0.19941464767555747
# RGB_022.png 0.19798273508837005
# RGB_023.png 0.22410638856204287
# RGB_024.png 0.1372917205894702
# RGB_026.png 0.20058414773196634
# RGB_027.png 0.17655489010791192
# RGB_028.png 0.16884683104353032
# RGB_030.png 0.10688824025533608
# RGB_031.png 0.11379765265379709
# RGB_032.png 0.15735550247797958
# RGB_034.png 0.1953855122882278
# RGB_036.png 0.23752829394308825
# RGB_037.png 0.09986008272225111
# RGB_038.png 0.15646806428922763
# RGB_040.png 0.29767345447497034
# RGB_041.png 0.29006413901951245
# RGB_043.png 0.3301225406910102
# RGB_044.png 0.16615116332430488
# RGB_045.png 0.31189036375599777
# RGB_046.png 0.20477019127120266
# RGB_047.png 0.14359731814663196
# RGB_048.png 0.1330009853945063
# RGB_049.png 0.2325457210921723
# RGB_050.png 0.20154193294631936
# RGB_051.png 0.1747409975518021
# RGB_053.png 0.21998778909097208
# RGB_054.png 0.09678944983725227
# RGB_162.png 0.2607180871631514
# RGB_163.png 0.26611595838119273
# RGB_164.png 0.25315807669597246
# RGB_165.png 0.13183113881060665
# RGB_166.png 0.20916588682183646
# RGB_167.png 0.15417517082260834
# RGB_168.png 0.21441209652306298
# RGB_169.png 0.18341147347733106
# RGB_171.png 0.27412016657174615
# RGB_172.png 0.2649762446726365
# RGB_173.png 0.18172819799356774
# RGB_174.png 0.26293714933630197
# RGB_175.png 0.2123118972359564
# RGB_176.png 0.12744461650509317
# RGB_177.png 0.22085400874061178
# RGB_178.png 0.2509118626909928
# RGB_179.png 0.13548409055073884
# RGB_180.png 0.1891168890910112
# RGB_183.png 0.14734232201314634
# RGB_184.png 0.1560460055952729
# RGB_185.png 0.19150206403939588
# RGB_186.png 0.2317339667458408
# RGB_187.png 0.13603762034614944
# RGB_188.png 0.18734747732141893
# RGB_191.png 0.20255376225305805
# RGB_193.png 0.22755723192046656
# RGB_194.png 0.2501288090993949
# RGB_195.png 0.2631630643700173
# RGB_196.png 0.09486161970306757
# RGB_197.png 0.12614554470592937
# RGB_198.png 0.16319825595983167
# RGB_199.png 0.12414724380318048
# RGB_200.png 0.11427072765043846
# RGB_201.png 0.2059512908504629
# RGB_202.png 0.2604460481157787
# RGB_203.png 0.19100430997250611
# RGB_204.png 0.2364717288041199
# RGB_205.png 0.22180008268712167
# RGB_207.png 0.23373668627614175
# RGB_208.png 0.22432109855299046
# RGB_209.png 0.22500366474952757
# RGB_210.png 0.24282536774542568
# RGB_211.png 0.24563142470226446
# RGB_213.png 0.09117103444297232
# RGB_216.png 0.18505003324737443
# RGB_217.png 0.19303652722514808
# RGB_218.png 0.24862336521004855
# RGB_219.png 0.26276985425921373
# RGB_220.png 0.222920630089032
# RGB_221.png 0.22080021654908508
# RGB_222.png 0.22767890308597022
# RGB_223.png 0.17754760558069074
# RGB_224.png 0.19768298093823813
# RGB_225.png 0.2239501575973561
# RGB_227.png 0.1964046326301377
# RGB_229.png 0.3355365361711761
# RGB_230.png 0.2821401311477246
# RGB_231.png 0.2886934515675118
# RGB_233.png 0.29461980728265563
# RGB_235.png 0.251954931226219
# RGB_236.png 0.2880183147075555
# RGB_238.png 0.1523346991579337
# RGB_239.png 0.20906968201988949
# RGB_240.png 0.21187157293888415
# RGB_241.png 0.27173079536122735
# RGB_242.png 0.2675105485232046
# RGB_244.png 0.2908634321862189
# RGB_245.png 0.2028787109896425
# RGB_246.png 0.23925054873978774
# RGB_249.png 0.19478228535830597
# RGB_250.png 0.20807325702889048
# RGB_251.png 0.20861720162916772
# RGB_252.png 0.21831881393861685
# RGB_255.png 0.24987904916791684
# RGB_256.png 0.23820757883511245
# RGB_257.png 0.27332042554077196
# RGB_258.png 0.2847522314087483
# mean AveragePrecision is 0.21453409243232321 over 200 images.
