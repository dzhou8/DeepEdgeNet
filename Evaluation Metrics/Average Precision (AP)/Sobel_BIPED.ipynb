# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import imageio
import numpy as np

# %%
def AveragePrecision(label, output):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	label_matrix = label.astype('float')
	output_matrix = output.astype('float')
	totalPrecision, numRel = 0, 0
	for i in range(len(label_matrix)):
		for j in range(len(label_matrix[i])):
			if label_matrix[i][j] == 255:
				numRel += 1
				totalPrecision += output_matrix[i][j] / 255
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return totalPrecision / numRel

# %%
gdrive_path = '/content/drive/My Drive/CS 230/Project/'
labels_path = gdrive_path + "datasets/BIPED/edges/edge_maps/train/rgbr/real/"
output_path = gdrive_path + "Canny Detector/Canny-Edge BIPED/sobel_output/"

img_name = os.listdir(labels_path)
outputs = os.listdir(output_path)

totalPrecision = 0
img_name.sort()
outputs.sort()
assert len(img_name) == len(outputs)

for i in range(len(img_name)):
  assert img_name[i].split('.')[0] == outputs[i].split('.')[0]
  label_img = imageio.imread(labels_path + img_name[i])
  output_img = imageio.imread(output_path + outputs[i])
  AP = AveragePrecision(label_img, output_img)
  totalPrecision += AP
  print(img_name[i], AP)

meanAveragePrecision = totalPrecision / len(img_name)
print("mean AveragePrecision is " + str(meanAveragePrecision) + " over " + str(len(img_name)) + " images.")
# Out:
# RGB_001.png 0.2107113054249068
# RGB_002.png 0.22384534356811753
# RGB_003.png 0.2171226359531153
# RGB_004.png 0.19288142708807268
# RGB_005.png 0.2599867746325685
# RGB_006.png 0.315750845648437
# RGB_007.png 0.1985817959995905
# RGB_009.png 0.19915366510660704
# RGB_011.png 0.23190776524188014
# RGB_012.png 0.20456391127968196
# RGB_013.png 0.19900465216912677
# RGB_014.png 0.24760652272787598
# RGB_015.png 0.22489769756152123
# RGB_016.png 0.19552237897944547
# RGB_018.png 0.2398723793002395
# RGB_019.png 0.22120251901232274
# RGB_020.png 0.20161427259879075
# RGB_021.png 0.23484914283348657
# RGB_022.png 0.22159426840881444
# RGB_023.png 0.1885979362243552
# RGB_024.png 0.18456079497456826
# RGB_026.png 0.22203728173713122
# RGB_027.png 0.21179254014986174
# RGB_028.png 0.20463207203425682
# RGB_030.png 0.16534808469348103
# RGB_031.png 0.14912091079399709
# RGB_032.png 0.21002894579292852
# RGB_034.png 0.23291656615157028
# RGB_036.png 0.25651551625412494
# RGB_037.png 0.15082054935541855
# RGB_038.png 0.16936864645591324
# RGB_040.png 0.3156522236224263
# RGB_041.png 0.27803392944383193
# RGB_043.png 0.35869667834729646
# RGB_044.png 0.19526985866620458
# RGB_045.png 0.347730035140171
# RGB_046.png 0.17297480252965028
# RGB_047.png 0.1598497284617014
# RGB_048.png 0.18968762034758233
# RGB_049.png 0.2582517866959268
# RGB_050.png 0.22728596340246712
# RGB_051.png 0.19716531522490413
# RGB_053.png 0.22772289499530837
# RGB_054.png 0.14965153530993835
