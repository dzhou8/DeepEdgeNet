# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import imageio
import numpy as np

# %%
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err

# %%
gdrive_path = '/content/drive/My Drive/CS 230/Project/'
labels_path = gdrive_path + "datasets/BIPED/edges/edge_maps/train/rgbr/real/"
output_path = gdrive_path + "datasets/BIPED/edges/edge_maps/train/rgbr/real/"

img_name = os.listdir(labels_path)
outputs = os.listdir(output_path)

totalMSE = 0
img_name.sort()
outputs.sort()
assert len(img_name) == len(outputs)

for i in range(len(img_name)):
  assert img_name[i].split('.')[0] == outputs[i].split('.')[0]
  label_img = imageio.imread(labels_path + img_name[i])
  output_img = imageio.imread(output_path + outputs[i])
  totalMSE += mse(label_img, output_img)
  print(img_name[i], mse(label_img, output_img))

averageMSE = totalMSE / len(img_name)
print("average MSE is " + str(averageMSE) + " over " + str(len(img_name)) + " images.")
# Out:
# RGB_001.png 0.0
# RGB_002.png 0.0
# RGB_003.png 0.0
# RGB_004.png 0.0
# RGB_005.png 0.0
# RGB_006.png 0.0
# RGB_007.png 0.0
# RGB_009.png 0.0
# RGB_011.png 0.0
# RGB_012.png 0.0
# RGB_013.png 0.0
# RGB_014.png 0.0
# RGB_015.png 0.0
# RGB_016.png 0.0
# RGB_018.png 0.0
# RGB_019.png 0.0
# RGB_020.png 0.0
# RGB_021.png 0.0
# RGB_022.png 0.0
# RGB_023.png 0.0
# RGB_024.png 0.0
# RGB_026.png 0.0
# RGB_027.png 0.0
# RGB_028.png 0.0
# RGB_030.png 0.0
# RGB_031.png 0.0
# RGB_032.png 0.0
# RGB_034.png 0.0
# RGB_036.png 0.0
# RGB_037.png 0.0
# RGB_038.png 0.0
# RGB_040.png 0.0
# RGB_041.png 0.0
# RGB_043.png 0.0
# RGB_044.png 0.0
# RGB_045.png 0.0
# RGB_046.png 0.0
# RGB_047.png 0.0
# RGB_048.png 0.0
# RGB_049.png 0.0
# RGB_050.png 0.0
# RGB_051.png 0.0
# RGB_053.png 0.0
# RGB_054.png 0.0
# RGB_055.png 0.0
# RGB_058.png 0.0
# RGB_060.png 0.0
# RGB_061.png 0.0
# RGB_062.png 0.0
# RGB_063.png 0.0
# RGB_064.png 0.0
# RGB_065.png 0.0
# RGB_068.png 0.0
# RGB_069.png 0.0
